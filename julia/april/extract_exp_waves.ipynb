# %%
# modules
using PyPlot
using Contour
using Images
# Out:
# INFO: Loading help data...

# %%
# my modules
using Various

# %%
# exp params
const NY = 200
const NX = 1024
const Δy = 0.64
const Δx = 0.16

const y = sider(;l=(NY-1)*Δy/2, n=NY)
const x = sider(;l=(NX-1)*Δx/2, n=NX)

const xdef, ydef = -11.2, -0.2

# read exp data
ctpmpdata, cexpx, cexpy = gettrunccrop("E-pump.dat", x, y; xcenter=xdef, ycenter=ydef)
ctidldata, cexpx, cexpy = gettrunccrop("E-idler.dat", x, y; xcenter=xdef, ycenter=ydef)
# Out:
# (
# 111x438 Array{Float64,2}:
#  4.39548  4.5015   4.66393  4.64059  4.74272  …  12.3247   12.4219   11.9687
#  4.18733  4.38575  4.68728  4.76606  4.7291      12.0329   12.2089   12.204
#  4.40423  4.40034  4.59488  4.81178  4.90029     11.8062   12.0241   12.1165
#  4.30308  4.46454  4.47913  4.7291   4.7933      12.6077   12.8479   12.7419
#  5.65022  5.59478  5.84475  6.01691  6.17838     12.987    13.0386   13.1631
#  5.24753  5.41872  5.45568  5.84961  6.1881   …  13.3158   13.4228   13.4228
#  4.89543  5.01118  5.28936  5.50724  5.80779     13.6864   13.7516   13.7652
#  4.99756  5.36814  5.59478  5.78445  6.04415     14.1912   13.8994   13.7418
#  4.98394  5.46541  5.69204  5.9605   6.10932     14.0939   14.1679   14.09
#  5.0209   5.48389  5.69691  6.21145  6.42835     14.3069   14.3439   14.2058
#  5.26115  5.55295  6.0208   6.31747  6.73474  …  14.6921   14.4791   14.5063
#  6.2202   7.01681  7.4798   7.99434  8.38827     15.5948   15.6084   15.4138
#  7.59166  8.00796  8.73065  9.47669  9.93968     15.979    15.7757   15.6269
#  ⋮                                            ⋱   ⋮
#  4.67755  4.7933   4.77093  4.96935  5.13179     10.3054   10.5466   10.3793
#  4.15426  4.37213  4.36338  4.59877  4.77482  …  10.3103   10.4912   10.356
#  4.38186  4.51998  4.73299  4.95087  5.29422     10.4581   10.532    10.7635
#  4.06672  4.29821  4.51998  4.78941  5.08996      9.99512   9.95329   9.79572
#  4.35852  4.56667  4.77482  5.18237  5.50237      9.66149   9.73153   9.8142
#  4.03851  4.27973  4.63184  5.08121  5.37301     10.0233   10.0642    9.92995
#  4.10854  4.25639  4.60363  4.77093  5.07148  …  10.4678   10.5602   10.3608
#  3.93638  4.12216  4.24277  4.42758  4.57639     11.1438   10.9814   11.209
#  4.30308  4.41396  4.68728  4.7933   5.02479     11.9725   12.0883   11.9774
#  3.78367  3.89066  3.90915  4.21456  4.07547     12.4686   12.2692   12.3577
#  3.52008  3.43643  3.56579  3.594    3.71461     12.705    12.8664   12.8295
#  3.26038  3.40433  3.55218  3.58525  3.61735  …  12.4871   12.3247   12.668  ,
#
# -46.16:0.16:23.76,-35.52:0.64:34.88)

# %%
# Gaussian filtering
sigma = [4, 4]
gaussctpmpdata = Images.imfilter_gaussian(ctpmpdata, sigma)
diffctpmpdata = ctpmpdata - gaussctpmpdata
gaussctidldata = Images.imfilter_gaussian(ctidldata, sigma)
diffctidldata = ctidldata - gaussctidldata;

# plotting gaussian filtered exp data
fig, axes = plt.subplots(2, 2, figsize=(10, 10))

axes[1,1][:imshow](gaussctpmpdata, ColorMap("gray"), origin="lower",
                            extent=[cexpx[1], cexpx[end], cexpy[1], cexpy[end]])
axes[1,2][:imshow](gaussctidldata, ColorMap("gray"), origin="lower",
                            extent=[cexpx[1], cexpx[end], cexpy[1], cexpy[end]])

axes[2,1][:imshow](diffctpmpdata, ColorMap("gray"), origin="lower",
                            extent=[cexpx[1], cexpx[end], cexpy[1], cexpy[end]])
axes[2,2][:imshow](diffctidldata, ColorMap("gray"), origin="lower",
                            extent=[cexpx[1], cexpx[end], cexpy[1], cexpy[end]])

for ax in axes
    ax[:scatter](xdef, ydef, s=40, c="orange", marker="o")
    ax[:set_ylim](cexpy[1], cexpy[end])
    ax[:set_xlim](cexpx[1], cexpx[end])
    ax[:set_xlabel](L"$x [\mu m]$")
    ax[:set_ylabel](L"$y [\mu m]$")
end

axes[1][:set_title]("pump")
axes[2][:set_title]("idler")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7fa74b1c6240>)
# PyObject <matplotlib.text.Text object at 0x7fa731eeb550>

# %%
y0pmp = 10.
# fill ct. array for plotting
vy0pmp = fill(y0pmp, size(cexpx));
# get corresponding index
idxy0pmp = getidx(y0pmp, maximum(cexpy), step(cexpy))
# check
cexpy[idxy0pmp] - y0pmp #0
# Out:
# -0.7200000000000006

# %%
y0idl = 15.
# fill ct. array for plotting
vy0idl = fill(y0idl, size(cexpx));
# get corresponding index
idxy0idl = getidx(y0idl, maximum(cexpy), step(cexpy))
# check
cexpy[idxy0idl] - y0idl #0
# Out:
# -0.5999999999999996

# %%
# plotting exp data in 2D
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

axes[1][:imshow](diffctpmpdata, ColorMap("gray"), origin="lower",
                            extent=[cexpx[1], cexpx[end], cexpy[1], cexpy[end]])
axes[2][:imshow](diffctidldata, ColorMap("gray"), origin="lower",
                            extent=[cexpx[1], cexpx[end], cexpy[1], cexpy[end]])

axes[1][:plot](cexpx, vy0pmp)
axes[2][:plot](cexpx, vy0idl)

for ax in axes
    ax[:scatter](xdef, ydef, s=40, c="orange", marker="o")
    ax[:set_ylim](cexpy[1], cexpy[end])
    ax[:set_xlim](cexpx[1], cexpx[end])
    ax[:set_xlabel](L"$x [\mu m]$")
    ax[:set_ylabel](L"$y [\mu m]$")
end

axes[1][:set_title]("pump")
axes[2][:set_title]("idler")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7fa731ed1eb8>)
# PyObject <matplotlib.text.Text object at 0x7fa731827710>

# %%
# extract the psi = 1. plane
levelpmp = 20.
levelidl = 5.
vlevelpmp = fill(levelpmp, size(cexpx))
vlevelidl = fill(levelidl, size(cexpx));

# %%
# plotting cuts through exp data
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

axes[1][:plot](cexpx, vec(diffctpmpdata[idxy0pmp, :])) 
axes[1][:grid]()

axes[2][:plot](cexpx, vec(diffctidldata[idxy0idl, :])) 
axes[2][:grid]()

axes[1][:plot](cexpx, vlevelpmp)
axes[2][:plot](cexpx, vlevelidl)

for ax in axes    
    #ax[:set_ylim](cexpy[1], cexpy[end])
    ax[:set_xlim](cexpx[1], cexpx[end])
    ax[:set_xlabel](L"$x [\mu m]$")
    #ax[:set_ylabel](L"$y [\mu m]$")
end

axes[1][:set_title]("pump")
axes[2][:set_title]("idler")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7fa731848be0>)
# PyObject <matplotlib.text.Text object at 0x7fa7317d7cf8>

# %%
cpmp = contour(cexpx, cexpy, diffctpmpdata', levelpmp);
cidl = contour(cexpx, cexpy, diffctidldata', levelidl);

# %%
# plotting waves on top
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

axes[1][:imshow](diffctpmpdata, ColorMap("gray"), origin="lower",
                            extent=[cexpx[1], cexpx[end], cexpy[1], cexpy[end]])
axes[2][:imshow](diffctidldata, ColorMap("gray"), origin="lower",
                            extent=[cexpx[1], cexpx[end], cexpy[1], cexpy[end]])

for line in cpmp.lines
    xs, ys = coordinates(line)
    axes[1][:plot](xs, ys, "y-")
end

for line in cidl.lines
    xs, ys = coordinates(line)
    axes[2][:plot](xs, ys, "y-")
end

for ax in axes    
    ax[:scatter](xdef, ydef, s=40, c="orange", marker="o")
    ax[:set_ylim](cexpy[1], cexpy[end])
    ax[:set_xlim](cexpx[1], cexpx[end])
    ax[:set_xlabel](L"$x [\mu m]$")
    ax[:set_ylabel](L"$y [\mu m]$")
end

axes[1][:set_title]("pump")
axes[2][:set_title]("idler")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7fa73185a860>)
# PyObject <matplotlib.text.Text object at 0x7fa731713f28>

# %%
# plotting waves on top
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

axes[1][:imshow](diffctpmpdata, ColorMap("gray"), origin="lower",
                            extent=[cexpx[1], cexpx[end], cexpy[1], cexpy[end]])
axes[2][:imshow](diffctidldata, ColorMap("gray"), origin="lower",
                            extent=[cexpx[1], cexpx[end], cexpy[1], cexpy[end]])

for line in cidl.lines
    xs, ys = coordinates(line)
    for ax in axes
        ax[:plot](xs, ys, "y-")
    end
end

for ax in axes    
    ax[:scatter](xdef, ydef, s=40, c="orange", marker="o")
    ax[:set_ylim](cexpy[1], cexpy[end])
    ax[:set_xlim](cexpx[1], cexpx[end])
    ax[:set_xlabel](L"$x [\mu m]$")
    ax[:set_ylabel](L"$y [\mu m]$")
end

axes[1][:set_title]("pump")
axes[2][:set_title]("idler")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7fa73178f160>)
# PyObject <matplotlib.text.Text object at 0x7fa731442fd0>
