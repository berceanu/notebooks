# %%
# modules
using PyPlot
using Contour
using NPZ
using IniFile
# Out:
# INFO: Loading help data...

# %%
# my modules
using Various

# %%
ini = Inifile()
read(ini, "/home/berceanu/notebooks/OPODrag/parameters.ini");

# %%
const Δk  = get_float(ini, "ks0.0", "delta_k")
const nkx = get_int(ini, "ks0.0", "nkx");

# %%
const sider = pi/Δk
const sidek = nkx*Δk/2
const Δr    = pi/sidek;

# %%
const xdef = ydef =0.;

# %%
const sbox = sysbox(-sider:Δr:sider-Δr, -sider:Δr:sider-Δr, -sidek:Δk:sidek-Δk, -sidek:Δk:sidek-Δk)
# Out:
# sysbox{Float64}(-62.83185307179586:0.1227184630308513:62.70913460876501,-62.83185307179586:0.1227184630308513:62.70913460876501,-25.6:0.05:25.55,-25.6:0.05:25.55)

# %%
run(`ipython2 /home/berceanu/notebooks/OPODrag/OPODrag-qt.py`)
# Out:
# PHCv2.3.86 released 2013-12-20 works!
# done!

# %%
resr = npzread("/home/berceanu/notebooks/OPODrag/res_r.npy");
# Out:
# 1024x1024x3 Array{Float64,3}:
# [:, :, 1] =
#  0.989301  0.989301  0.989303  0.98931   …  0.989318  0.989311  0.989305
#  0.989302  0.989301  0.989304  0.98931      0.989319  0.989312  0.989306
#  0.989303  0.989302  0.989305  0.989311     0.989319  0.989312  0.989307
#  0.989305  0.989304  0.989307  0.989313     0.98932   0.989314  0.989308
#  0.989308  0.989307  0.98931   0.989316     0.989322  0.989316  0.989311
#  0.989311  0.989311  0.989314  0.98932   …  0.989324  0.989319  0.989314
#  0.989315  0.989315  0.989318  0.989324     0.989327  0.989322  0.989318
#  0.989321  0.989321  0.989324  0.989329     0.98933   0.989326  0.989322
#  0.989326  0.989327  0.98933   0.989335     0.989334  0.989331  0.989328
#  0.989333  0.989334  0.989337  0.989341     0.989339  0.989336  0.989334
#  0.98934   0.989341  0.989344  0.989349  …  0.989344  0.989342  0.98934
#  0.989348  0.98935   0.989352  0.989357     0.989349  0.989348  0.989348
#  0.989357  0.989359  0.989362  0.989365     0.989355  0.989355  0.989356
#  ⋮                                       ⋱
#  0.989357  0.989359  0.989362  0.989365     0.989355  0.989355  0.989356
#  0.989348  0.98935   0.989352  0.989357     0.989349  0.989348  0.989348
#  0.98934   0.989341  0.989344  0.989349     0.989344  0.989342  0.98934
#  0.989333  0.989334  0.989337  0.989341  …  0.989339  0.989336  0.989334
#  0.989326  0.989327  0.98933   0.989335     0.989334  0.989331  0.989328
#  0.989321  0.989321  0.989324  0.989329     0.98933   0.989326  0.989322
#  0.989315  0.989315  0.989318  0.989324     0.989327  0.989322  0.989318
#  0.989311  0.989311  0.989314  0.98932      0.989324  0.989319  0.989314
#  0.989308  0.989307  0.98931   0.989316  …  0.989322  0.989316  0.989311
#  0.989305  0.989304  0.989307  0.989313     0.98932   0.989314  0.989308
#  0.989303  0.989302  0.989305  0.989311     0.989319  0.989312  0.989307
#  0.989302  0.989301  0.989304  0.98931      0.989319  0.989312  0.989306
#
# [:, :, 2] =
#  1.00322  1.00317  1.00308  1.00296  …  1.00301  1.00311  1.00318  1.00322
#  0.996958  0.99697   0.996988  0.997011     0.996974  0.99696   0.996955
#  0.996949  0.996962  0.996984  0.997011  …  0.996971  0.996953  0.996945
#  0.99694   0.996955  0.99698   0.997011     0.996969  0.996946  0.996937
#  0.996931  0.996948  0.996976  0.997011     0.996966  0.996941  0.996929
#  0.996924  0.996942  0.996972  0.997011     0.996964  0.996935  0.996922
#  0.996918  0.996936  0.996969  0.997011     0.996962  0.996931  0.996915
#  0.996912  0.996932  0.996966  0.997011  …  0.996961  0.996927  0.99691
#  0.996908  0.996928  0.996964  0.997011     0.996959  0.996924  0.996906
#  0.996905  0.996926  0.996963  0.997011     0.996958  0.996921  0.996903
#  0.996903  0.996924  0.996962  0.997011     0.996958  0.99692   0.996901

# %%
const pump = resr[:,:,2]
const idler = resr[:,:,3];

# %%
# crop data
const cpmpdata, cx, cy = cropmat(pump, sbox.x, sbox.y; xcenter=xdef, ycenter=ydef, side=10.)
const cidldata, cx, cy = cropmat(idler, sbox.x, sbox.y; xcenter=xdef, ycenter=ydef, side=10.);

# %%
# Gaussian filtering
const gausscpmpdata, diffcpmpdata = filtergauss(cpmpdata, [4., 4.])
const gausscidldata, diffcidldata = filtergauss(cidldata, [4., 4.]);

# %%
# plotting cuts through data
fig, axes = plt.subplots(2, 2, figsize=(10, 10))

sliceplot(vec(axes[1,:]), diffcpmpdata, cx, cy, "pump"; y0=0., level=0.005)
const cpmp = contour(cx, cy, transpose(diffcpmpdata), 0.);

sliceplot(vec(axes[2,:]), diffcidldata, cx, cy, "idler"; y0=0., level=0.)
const cidl = contour(cx, cy, transpose(diffcidldata), 0.);

for ax in axes
    ax[:set_xlim](cx[1], cx[end])
    ax[:set_xlabel](L"$x [\mu m]$")
end

for ax in axes[:, 2]
    ax[:grid]()
end

for ax in axes[:, 1]
    ax[:scatter](xdef, ydef, s=40, c="orange", marker="o")
    ax[:set_ylim](cy[1], cy[end])
    ax[:set_ylabel](L"$y [\mu m]$")
end
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f6e9657d198>)

# %%
# plotting waves on top
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

axes[1][:imshow](diffcpmpdata, ColorMap("gray"), origin="lower",
                            extent=[cx[1], cx[end], cy[1], cy[end]])
axes[1][:set_title]("pump")

axes[2][:imshow](diffcidldata, ColorMap("gray"), origin="lower",
                            extent=[cx[1], cx[end], cy[1], cy[end]])
axes[2][:set_title]("idler")

for ax in axes
    plotcontours(cpmp, ax)
end

for ax in axes    
    ax[:scatter](xdef, ydef, s=40, c="orange", marker="o")
    ax[:set_ylim](cy[1], cy[end])
    ax[:set_xlim](cx[1], cx[end])
    ax[:set_xlabel](L"$x [\mu m]$")
    ax[:set_ylabel](L"$y [\mu m]$")
end
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f6e7d0006d8>)

# %%
# plotting cuts through data
fig, ax = plt.subplots(1, 1, figsize=(10, 4))

ax[:plot](cx, vec(diffcpmpdata[div(length(cy),2), :])) 
ax[:plot](cx, vec(diffcidldata[div(length(cy),2), :])) 

ax[:set_xlim](cx[1], cx[end])
ax[:set_xlabel](L"$x [\mu m]$")

ax[:grid]()
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f6e7cc8e828>)
