# %%
from IPython.core.display import Image

# %% [markdown]
# Linear response
# ===============

# %% [markdown]
# $k_s = -0.4\, \mu m^{-1}$

# %%
Image(filename="pngs/ks-0.4-2D.png")

# %%
Image(filename="pngs/ks-0.4-1D.png")

# %% [markdown]
# $k_s = 0\, \mu m^{-1}$

# %%
Image(filename="pngs/ks0.0-2D.png")

# %%
Image(filename="pngs/ks0.0-1D.png")

# %% [markdown]
# $k_s = 0.7\, \mu m^{-1}$

# %%
Image(filename="pngs/ks0.7-2D.png")

# %%
Image(filename="pngs/ks0.7-1D.png")

# %% [markdown]
# **Effect of simultaneous and opposite phase shift of signal and idler**
