# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from importlib import reload

# %%
import plotz

# %%
reload(plotz)
# Out:
# <module 'plotz' from '/home/berceanu/.local/lib/python3.6/site-packages/plotz.py'>

# %%
uu = np.linspace(0, np.pi, 128)
data = np.cos(uu - 0.5) * np.cos(uu.reshape(-1, 1) - 1.0)

# %%
plt.plot(uu, data[10,:])

# %%
data.shape
# Out:
# (128, 128)

# %%
uu.shape
# Out:
# (128,)

# %%
p2d = plotz.Plot2D(data, uu, uu, xlabel=r'$x$ ($\mu$m)',
                   ylabel=r'$y$ ($\mu$m)', zlabel=r'$\rho$ (cm$^{-3}$)')

# %%
p2d.slice(figsize=(6.4, 6.4), hslice_pos=100,vslice_pos=10,
         vslice_opts={'ls':'--', 'color':'green'}, hslice_opts={'ls':'-', 'color':'red'})

# %%
p2d.cbar(cmap='hot')
