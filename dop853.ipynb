# %%
include("dop853.jl")
# Out:
# dopcore (generic function with 1 method)

# %%
function gravity!(f::Vector{Float64}, t::Float64, y::Vector{Float64})
    r = sqrt(y[1]*y[1]+y[2]*y[2]+y[3]*y[3])
    r3 = r*r*r
    f[1] = y[4]
    f[2] = y[5]
    f[3] = y[6]
    f[4] = -mu*y[1]/r3
    f[5] = -mu*y[2]/r3
    f[6] = -mu*y[3]/r3
end
# Out:
# gravity! (generic function with 1 method)

# %%
const mu = 398600.4415 # [km^3/s^2] Earth's gravity
const s0 = [-1814.0, -3708.0, 5153.0, 6.512, -4.229, -0.744]
const tp = 5402.582703094263*16
# Out:
# 86441.3232495082

# %%
output = dop853(gravity!, s0, [0.0:tp])
# Out:
# error is 1.5318146347902687e-19
# 1.0e-7
# error is 1.770881869452361e-18
# 7.0e-7
# error is 3.3414884851316322e-18
# 4.2999999999999995e-6
# error is 1.3243746131416208e-16
# 2.59e-5
# error is 2.731703513776091e-17
# 0.0001555
# error is 1.4898267483144399e-16
# 0.0009331000000000001
# error is 2.562257372288753e-15
# 0.005598700000000001
# error is 3.4620125946986305e-14
# 0.033592300000000005
# error is 2.9505419318046185e-13
# 0.20155390000000006
# error is 8.129844129353363e-15
# 1.2093235000000004
# error is 3.9500374403053316e-16
# 7.255941100000003
# error is 7.278775438261782e-11
# 43.535646700000015
# error is 0.00010289332873003553
# 261.2138803000001
# error is 0.4278730280074006
# 878.5321239101625
# error is 0.30199221680042504
# 1496.3169790805537
# error is 0.4468128465177059
# 2142.0905963240857
# error is 0.4717908183711823
# 2784.8628200131798
# error is 0.3942394954380404
# 3420.3121484312032
# error is 0.4311970459432227
# 4062.782984269829
# error is 0.5411323296823293
# 4705.117790101463
# error is 0.3944208660119826
# 5329.342605775338
# error is 0.42152404882625805
# 5960.428617445603
# error is 0.45810030774966387
# 6593.172957042945
# error is 0.38978260951128774
# 7221.0154491707635
# error is 0.3512877345048356
# 7856.698171107555
# error is 0.5161162920584316
# 8508.739379308861
# error is 0.49929222973029647
# 9146.157061595477
# error is 0.33406993018586356
# 9771.865865067746
# error is 0.4359077689697651
# 10417.720977236335
# error is 0.6598386077832663
# 11062.562930476764
# error is 0.39367136824578275
# 11673.879375452045
# error is 0.30538704135352396
# 12292.062093307562
# error is 0.44798985404353864
# 12937.349282920766
# error is 0.46434087199241736
# 13579.4261608098
# error is 0.3943301824706582
# 14215.45224359841
# error is 0.4369989724323053
# 14858.487718909379
# error is 0.542546108413382
# 15500.313843493994
# error is 0.3881040075694491
# 16123.840921339299
# error is 0.4268550045913586
# 16755.495010238767
# error is 0.4597197425947316
# 17387.814799822034
# error is 0.3827659625984441
# 18014.959330484162
# error is 0.352460987645943
# 18651.37884020224
# error is 0.5229505643715656
# 19303.903775666426
# error is 0.4989505470995326
# 19940.746281174208
# error is 0.3290186538333901
# 20565.94396994861
# error is 0.4420225191600042
# 21212.50169967341
# error is 0.6649536711464334
# 21856.922081906276
# error is 0.3842053949396478
# 22467.249462960903
# error is 0.3110931184164467
# 23086.312581556733
# error is 0.4493171718497277
# 23731.025155005722
# error is 0.4559023918332657
# 24372.29308674745
# error is 0.3944971453190587
# 25008.975784860715
# error is 0.4436921154977443
# 25652.641051415674
# error is 0.544145075349129
# 26293.87627412979
# error is 0.3809798657643721
# 26916.600184596507
# error is 0.43337565716582954
# 27548.90326538917
# error is 0.4613871684820542
# 28180.674347433694
# error is 0.37474071400861564
# 28806.991150873186
# error is 0.353897956276045
# 29444.256365486828
# error is 0.5308930491566424
# 30097.316187450426
# error is 0.49847506948542897
# 30733.480928686036
# error is 0.32333537833697223
# 31358.08768010403
# error is 0.44956576074814014
# 32005.442715368674
# error is 0.6706624046461828
# 32649.294474141978
# error is 0.37337348672033105
# 33258.43206395039
# error is 0.3179167354116184
# 33878.50100115564
# error is 0.45083500310629177
# 34522.5120395639
# error is 0.4461133654049576
# 35162.8122097614
# error is 0.39481946800408224
# 35800.261251154676
# error is 0.4515722893450477
# 36444.635478573524
# error is 0.5459733371081957
# 37085.16589985632
# error is 0.37277584756274085
# 37706.94460063001
# error is 0.44157713862781506
# 38340.00825400515
# error is 0.4631487743113021
# 38971.05868332565
# error is 0.3653395863638367
# 39596.36312141664
# error is 0.35576484555323157
# 40234.62209422068
# error is 0.540294116575555
# 40888.270278957185
# error is 0.49777351742738685
# 41523.61260556308
# error is 0.3168562755384639
# 42147.52171275112
# error is 0.45906737974556394
# 42795.79189360551
# error is 0.6772770724837491
# 43438.87040913606
# error is 0.36068378707133897
# 44046.53049865742
# error is 0.3263137647352006
# 44667.77476724917
# error is 0.4526571657384844
# 45310.90730215391
# error is 0.4344524083356527
# 45950.0117128253
# error is 0.3954771483477911
# 46588.380358742426
# error is 0.4610160269683537
# 47233.5499405738
# error is 0.5480591691440977
# 47873.21391148362
# error is 0.36312546645772403
# 48493.85563487153
# error is 0.45224156821356676
# 49127.836848928324
# error is 0.4650851431154702
# 49757.91959730221
# error is 0.3540304850972238
# 50381.93964156092
# error is 0.3583965212911166
# 51021.39608354608
# error is 0.5515656390786856
# 51675.66758388792
# error is 0.4966526283236196
# 52309.97656733599
# error is 0.3094394054115443
# 52933.04647880348
# error is 0.47127229240676893
# 53582.36432070249
# error is 0.6480387207532572
# 54224.372938338536
# error is 0.3654297858007368
# 54834.37773152666
# error is 0.3358628325481302
# 55457.00088115986
# error is 0.4545161311639765
# 56099.241146467626
# error is 0.4230812909435196
# 56737.132002897044
# error is 0.39655141991749737
# 57376.40433555464
# error is 0.4701093985385207
# 58022.26818929277
# error is 0.5279430114203345
# 58661.05894458826
# error is 0.3683214268174277
# 59283.75734640975
# error is 0.46280016748449865
# 59918.71079673884
# error is 0.4665661727362133
# 60547.94193851541
# error is 0.34493692141246884
# 61170.87095618068
# error is 0.36095797970036464
# 61811.28907564445
# error is 0.5603933768446602
# 62465.961486833265
# error is 0.48415713891958767
# 63099.40067053347
# error is 0.31089422433761027
# 63723.60121290499
# error is 0.4809730852982321
# 64373.71603749306
# error is 0.6271385538082609
# 65014.87760503859
# error is 0.36893016787887156
# 65626.57911696838
# error is 0.3430323687429792
# 66250.19051184284
# error is 0.4559511570621988
# 66891.75403527706
# error is 0.4147285655184222
# 67528.72169533231
# error is 0.3977323256877272
# 68168.66190426586
# error is 0.4765685058428915
# 68814.96025399382
# error is 0.5127332022610083
# 69453.09132192082
# error is 0.37267730044957853
# 70077.42385845984
# error is 0.4710714018977216
# 70713.10870701562
# error is 0.46765147199826335
# 71341.67129346586
# error is 0.3382209381198659
# 71963.7577529034
# error is 0.36320386519801856
# 72604.88346825124
# error is 0.5666288401638654
# 73259.77126586044
# error is 0.47312231325747484
# 73892.54300346105
# error is 0.3134152926871296
# 74517.88544367686
# error is 0.48812143697900556
# 75168.53238200455
# error is 0.6122806503401093
# 75809.03648306536
# error is 0.37134883800892243
# 76421.94493096745
# error is 0.34844826888177904
# 77046.2765902787
# error is 0.45707351416538744
# 77687.32463329445
# error is 0.4084961792512779
# 78323.58494095046
# error is 0.39890151960648473
# 78964.0255188264
# error is 0.4811761818038861
# 79610.59192903472
# error is 0.5018225731316543
# 80248.22030074683
# error is 0.3757622044200539
# 80873.74054307087
# error is 0.47756599689474977
# 81509.97874330648
# error is 0.46848550449865595
# 82138.01262743968
# error is 0.33312728262483954
# 82759.4374048757
# error is 0.36516531076027275
# 83401.09715762954
# error is 0.571110195295706
# 84056.08934483014
# error is 0.46492309761673595
# 84688.33905658615
# error is 0.3154661404971451
# 85314.53249007795
# error is 0.4935098954693621
# 85965.53389301927
# error is 0.05392767773939777
# 86441.0
# 6-element Array{Float64,1}:
#  -1815.5
#  -3707.03
#   5153.17
#      6.51142
#     -4.23016
#     -0.742371

# %%
println(abs(s0-output))
# Out:
# [1
# .4965354466608005,0.969532912242812,0.17335055439889402,0.0005835597233128098,0.0011647846403404216,0.0016292948669784924]

# %%
function rhsexp!(f::Vector{Float64}, t::Float64, y::Vector{Float64})
    f[1] = y[1]
end
# Out:
# rhsexp! (generic function with 1 method)

# %%
# dy
# -- = y ==> y = y0*e.^t
# dt

dop853(rhsexp!, [1.], [0.:2.]) .- e^2
# Out:
# error is 5.1370102384103565e-18
# 1.0e-7
# error is 1.8268742394549133e-16
# 7.0e-7
# error is 4.746425956071723e-17
# 4.2999999999999995e-6
# error is 1.3600346883561283e-15
# 2.59e-5
# error is 3.2436740858573136e-16
# 0.0001555
# error is 1.6771537099133267e-16
# 0.0009331000000000001
# error is 1.4860420975973373e-18
# 0.005598700000000001
# error is 1.5469680302932388e-13
# 0.033592300000000005
# error is 2.1204680673434075e-7
# 0.20155390000000006
# error is 0.10191111848668055
# 1.2093235000000004
# error is 0.02037583289788079
# 2.0
# 1-element Array{Float64,1}:
#  -3.8337e-7

# %%
# dv       dw
# -- = -w, -- = v ==> v = v0*cos(t) - w0*sin(t), w = w0*cos(t) + v0*sin(t)
# dt       dt

# y = [v, w]

# %%
function rhsvw!(f::Vector{Float64}, t::Float64, y::Vector{Float64})
    f[1] = -y[2]
    f[2] = y[1]
end
# Out:
# rhsvw! (generic function with 1 method)

# %%
dop853(rhsvw!, [1., 2.], [0.:2pi])
# Out:
# error is 1.6616626871540581e-18
# 1.0e-7
# error is 5.5198402322031846e-17
# 7.0e-7
# error is 3.20293305304979e-17
# 4.2999999999999995e-6
# error is 2.459898492684915e-15
# 2.59e-5
# error is 5.384266233438116e-16
# 0.0001555
# error is 2.3292078716518e-16
# 0.0009331000000000001
# error is 4.3174601133305454e-18
# 0.005598700000000001
# error is 1.6228471073229222e-13
# 0.033592300000000005
# error is 2.8328587270804363e-7
# 0.20155390000000006
# error is 0.3345109896090318
# 1.1967860519350428
# error is 0.5422349245435185
# 2.223892861534596
# error is 0.3134730168624242
# 3.2217874838129426
# error is 0.5492553126536378
# 4.260038037015415
# error is 0.43708752820259833
# 5.267138735863837
# error is 0.02454675021349548
# 6.0
# 2-element Array{Float64,1}:
#  1.519
#  1.64092

# %%
tmp = 6.
[cos(tmp)-2*sin(tmp) 2*cos(tmp)+sin(tmp)]
# Out:
# 1x2 Array{Float64,2}:
#  1.519  1.64093

# %%
#= mem = @allocated dop853(gravity!, 0.0, s0, tp, mu)  =#
#= el = 0.0 =#
#= n = 1000 =#
#= for i = 1:n =#
#= el += @elapsed dop853(gravity!, 0.0, s0, tp, mu)  =#
#= end =#
#= println("Allocated memory: $mem") =#
#= println("Time per loop: $(el/n)") =#

# %%
#@iprofile clear
#output = dop853(gravity, 0.0, s0, tp, mu)
#@iprofile report

# %%
#@profile (for i=1:100; dop853(gravity!, 0.0, s0, tp*16, mu); end)
#Profile.print(format=:flat)
#
