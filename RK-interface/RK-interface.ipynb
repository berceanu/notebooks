# %% [markdown]
# Create our 'fortran code', which generates data every 5 seconds

# %%
# %%writefile fortran-code
# #!/usr/bin/env python
# import sys
# import time
# import numpy as np
#
# n = int(sys.argv[1])
#
# t = np.linspace(0,np.pi)
#
# for omega in range(1,n):
#     time.sleep(5)
#     y = np.sin(omega * t)
#     with open("data_%03i.dat" % omega, 'w') as f:
#         np.save(f, y)
# Out:
# Overwriting fortran-code

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np
import string

# %% [markdown]
# Define a function that plots a given data file

# %%
#conversion factor, in mu
lC = 0.868

# %%
x_label = r'$x[\mu m]$'
y_label = r'$y[\mu m]$'

# %%
#vertical axis
Ny = 80
Ly = 20.
y, a_y = np.linspace(-Ly, Ly, num=Ny, endpoint=False, retstep=True)

#side_ky = np.pi/a_y
#ky, delta_ky = np.linspace(-(2*(Ny-1)/float(Ny) - 1)*side_ky, side_ky, num=Ny, retstep=True)

# %%
#horizontal axis
Nx = 80
Lx = 20.
x, a_x = np.linspace(-Lx, Lx, num=Nx, endpoint=False, retstep=True)

#side_kx = np.pi/a_x
#kx, delta_kx = np.linspace(-(2*(Nx-1)/float(Nx) - 1)*side_kx, side_kx, num=Nx, retstep=True)

# %%
rule = string.maketrans('D', 'E')
data = np.loadtxt('/home/berceanu/notebooks/phcplx-opo_spc1.dat', usecols=(2,3),\
                  converters = {2: lambda val: float(val.translate(rule)),\
                                3: lambda val: float(val.translate(rule))})
psiC = data[:, 0]**2 + data[:, 1]**2
psiC.shape = ((Ny, Nx))

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 5))

ax.imshow(psiC, cmap=cm.binary, origin='lower', extent=lC * np.array([x[0], x[-1], y[0], y[-1]]))
ax.set_title(r'$\vert\psi_C\vert^2$')

ax.set_ylabel(y_label)
ax.set_xlabel(x_label)

# %%
def plot_fname(fname):
    with open(fname) as f:
        data = np.loadtxt(f, usecols=(2,3))
    plt.plot(data)
    plt.title(fname)
    plt.show()

# %% [markdown]
# Start the "fortran" code:

# %%
from subprocess import Popen
p = Popen(['./RK_OPO_rk.out', '5'])
p.poll()

# %% [markdown]
# Watch the data files, and plot them as they become available

# %%
import glob
import os
import time
from IPython.display import clear_output

last_seen = None

def mtime(fname):
    return os.stat(fname).st_mtime

previous = None

tic = time.time()
while p.poll() is None: # while the subprocess is running
    time.sleep(1)
    print("elapsed: %.0f" % (time.time() - tic))
    fnames = glob.glob("data_*.dat")
    if not fnames:
        # no data files
        continue
    # get the most recently modified file
    latest = sorted(fnames, key=mtime)[-1]
    # if the most recent file is not the currently displayed plot,
    # clear the output and make a new plot
    if latest != previous:
        previous = latest
        clear_output(wait=True)
        plot_fname(latest)
    
print("done")
# Out:
# done

# %%
times = [ mtime(fname) for fname in sorted_fnames ]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-5a9633e131fd> in <module>()
# ----> 1 times = [ mtime(fname) for fname in sorted_fnames ]
#
# NameError: name 'sorted_fnames' is not defined
