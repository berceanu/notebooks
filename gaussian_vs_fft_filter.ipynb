# %%
import numpy as np
import scipy.ndimage
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %%
def tukeywin(window_length, alpha=0.5):
    '''The Tukey window, also known as the tapered cosine window, can be regarded as a cosine lobe of width \alpha * N / 2
    that is convolved with a rectangle window of width (1 - \alpha / 2). At \alpha = 1 it becomes rectangular, and
    at \alpha = 0 it becomes a Hann window. 
    '''
    # Special cases
    if alpha <= 0:
        return np.ones(window_length) #rectangular window
    elif alpha >= 1:
        return np.hanning(window_length)
 
    # Normal case
    x = np.linspace(0, 1, window_length)
    w = np.ones(x.shape)
 
    # first condition 0 <= x < alpha/2
    first_condition = x<alpha/2
    w[first_condition] = 0.5 * (1 + np.cos(2*np.pi/alpha * (x[first_condition] - alpha/2) ))
 
    # second condition already taken care of
 
    # third condition 1 - alpha / 2 <= x <= 1
    third_condition = x>=(1 - alpha/2)
    w[third_condition] = 0.5 * (1 + np.cos(2*np.pi/alpha * (x[third_condition] - 1 + alpha/2))) 
 
    return w

# %% [markdown]
# # Loading input file

# %%
sig = np.genfromtxt('/home/andreiberceanu/Dropbox/GP_data/OPO/tophat/defect/kp/1.4/fp/0.11/N/256/move_defect/spectrum_2048/opo_ph-spc_enfilt_signal.dat')

# %%
rescale = 0.868
N = int(np.sqrt(sig[:, 2].size))
X = sig[:N, 0] * rescale
data = sig[:, 2].reshape(N, N)

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 6))
ax.imshow(data[95:159,116:180], cmap=cm.binary)

# %% [markdown]
# # Gaussian filtering

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 6))
ax.imshow(data[95:159,116:180] - scipy.ndimage.filters.gaussian_filter(data[95:159,116:180],1), cmap=cm.binary)

# %% [markdown]
# # Fourier transform

# %%
data_fft = np.fft.fftshift(np.fft.fft2(data))

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 6))
ax.imshow(np.log10(np.abs(data_fft)), cmap=cm.binary)

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 6))
ax.imshow(np.log10(np.abs(data_fft))[72:184,72:184], cmap=cm.binary)

# %% [markdown]
# ## Tukey window

# %%
tw = tukeywin(112,0.6)
tw_2d = np.outer(tw,tw)

# %%
fig, axes = plt.subplots()

axes.plot(tw)
axes.set_ylim([-0.1, 1.1])
axes.set_xlim([0, 111]);

# %%
mask = np.zeros((N, N))
mask[72:184,72:184] = tw_2d

# %% [markdown]
# ## Applying mask

# %%
low_pass_data = data_fft * mask
high_pass_data = data_fft - low_pass_data

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 6))
ax.imshow(np.fft.ifft2(np.fft.ifftshift(low_pass_data)).real[95:159,116:180], cmap=cm.binary)

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 6))
ax.imshow(np.fft.ifft2(np.fft.ifftshift(high_pass_data)).real[95:159,116:180], cmap=cm.binary)

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 12))
axes[0].imshow(np.fft.ifft2(np.fft.ifftshift(high_pass_data)).real[95:159,116:180], cmap=cm.binary)
axes[1].imshow(data[95:159,116:180] - scipy.ndimage.filters.gaussian_filter(data[95:159,116:180],1), cmap=cm.binary)

# %% [markdown]
# <img src="files/images/tmp.png">
